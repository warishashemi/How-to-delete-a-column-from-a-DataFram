# %%
import pandas as pd
data=pd.read_csv('math_score_data.csv')

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['LSD_ppm']
# Out:
# 0    1.17
# 1    2.97
# 2    3.26
# 3    4.69
# 4    5.83
# 5    6.00
# 6    6.41
# Name: LSD_ppm, dtype: float64

# %%
Time_delay=data['Time_Delay_in_Minutes']

# %%
print(Time_delay)
# Out:
# 0      5
# 1     15
# 2     30
# 3     60
# 4    120
# 5    240
# 6    480
# Name: Time_Delay_in_Minutes, dtype: int64

# %%
type(Time_delay)
# Out:
# pandas.core.series.Series

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['New_Data'] = 'Data Science'

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score      New_Data
# 0                      5     1.17                78.93  Data Science
# 1                     15     2.97                58.20  Data Science
# 2                     30     3.26                67.47  Data Science
# 3                     60     4.69                37.47  Data Science
# 4                    120     5.83                45.65  Data Science
# 5                    240     6.00                32.92  Data Science
# 6                    480     6.41                29.97  Data Science

# %%
data['score']= 20

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score      New_Data  score
# 0                      5     1.17                78.93  Data Science     20
# 1                     15     2.97                58.20  Data Science     20
# 2                     30     3.26                67.47  Data Science     20
# 3                     60     4.69                37.47  Data Science     20
# 4                    120     5.83                45.65  Data Science     20
# 5                    240     6.00                32.92  Data Science     20
# 6                    480     6.41                29.97  Data Science     20

# %%
data['score']= data['Avg_Math_Test_Score'] + data['LSD_ppm']

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score      New_Data  score
# 0                      5     1.17                78.93  Data Science  80.10
# 1                     15     2.97                58.20  Data Science  61.17
# 2                     30     3.26                67.47  Data Science  70.73
# 3                     60     4.69                37.47  Data Science  42.16
# 4                    120     5.83                45.65  Data Science  51.48
# 5                    240     6.00                32.92  Data Science  38.92
# 6                    480     6.41                29.97  Data Science  36.38

# %%
data['score'] += data['LSD_ppm']

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score      New_Data  score
# 0                      5     1.17                78.93  Data Science  81.27
# 1                     15     2.97                58.20  Data Science  64.14
# 2                     30     3.26                67.47  Data Science  73.99
# 3                     60     4.69                37.47  Data Science  46.85
# 4                    120     5.83                45.65  Data Science  57.31
# 5                    240     6.00                32.92  Data Science  44.92
# 6                    480     6.41                29.97  Data Science  42.79

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score      New_Data  score
# 0                      5     1.17                78.93  Data Science  81.27
# 1                     15     2.97                58.20  Data Science  64.14
# 2                     30     3.26                67.47  Data Science  73.99
# 3                     60     4.69                37.47  Data Science  46.85
# 4                    120     5.83                45.65  Data Science  57.31
# 5                    240     6.00                32.92  Data Science  44.92
# 6                    480     6.41                29.97  Data Science  42.79

# %%
del data['New_Data']

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score  score
# 0                      5     1.17                78.93  81.27
# 1                     15     2.97                58.20  64.14
# 2                     30     3.26                67.47  73.99
# 3                     60     4.69                37.47  46.85
# 4                    120     5.83                45.65  57.31
# 5                    240     6.00                32.92  44.92
# 6                    480     6.41                29.97  42.79

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type('Time_delay')
# Out:
# str
